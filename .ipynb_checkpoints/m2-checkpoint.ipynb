# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
score=pd.read_excel("D:\\Desktop\\Python\\Matplotlib\\Cricket_1_2.xlsx")
score.head()
# Out:
#    Overs   Player Name  Runs  Balls  Unnamed: 4            Player Score Dots  \
# 0      1       Cubarsi    13      6         NaN       Virat Kohli    60    3
# 1      2      Van Djik    16      6         NaN  Ravindra Jadeja     47    1
# 2      3  Sergio Ramos    20      6         NaN    Shikhar Dhawan    28    4
# 3      4       Cubarsi    11      6         NaN    Jasprit Bumrah    20    3
# 4      5         Pedri    16      6         NaN     Parthiv Patel    22    1
#
#   Singles Singles Runs  ... Doubles Runs Triples Triple Runs Fours Fours Runs  \
# 0       0            0  ...            6       1           3     6         24
# 1       7            7  ...            6       3           9     1          4
# 2       3            3  ...            0       2           6     1          4
# 3       2            2  ...            0       1           3     1          4
# 4       0            0  ...            2       3           9     0          0
#
# ...

# %%
w=list(range(0,25,2))
x=score['Overs']
z=score['Runs']
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.grid(True)
plt.yticks(w)
plt.plot(x,z)
plt.show()

# %%
zax=pd.read_excel("D:\\Desktop\\Python\\Matplotlib\\Cricket_1_2.xlsx")
zax.tail()
# Out:
#     Overs   Player Name  Runs  Balls  Unnamed: 4   Player Score Dots Singles  \
# 15     16      Van Djik    12      6         NaN  Cubarsi     2   47      24
# 16     17  Sergio Ramos    10      6         NaN  Kimmich     1   33      12
# 17     18         Pedri    19      6         NaN     Gavi     0   22      12
# 18     19       Cubarsi    13      6         NaN    Pedri     1   48      20
# 19     20         Pedri     2      2         NaN      NaN   NaN  NaN     NaN
#
#    Singles Runs  ... Doubles Runs Triples Triple Runs Fours Fours Runs Sixes  \
# 15            4  ...            4       3          18    22          5     0
# 16            2  ...            8       0           0     8          1     1
# 17            2  ...            8       0           0     8          2     2
# 18          3.2  ...           20       0           0    20          5     1
# 19          NaN  ...          NaN     NaN         NaN   NaN        NaN   NaN
#
# ...

# %%
a=zax['Overs']
b=zax['Runs']
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.bar(a,b)
plt.show()
