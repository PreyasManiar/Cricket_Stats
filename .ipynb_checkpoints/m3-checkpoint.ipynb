# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
z=np.random.normal(20,1.5,100)
plt.hist(z)
plt.show()

# %%
cb=pd.read_excel("D:\\Desktop\\Python\\Matplotlib\\Cricket_1_2.xlsx")
